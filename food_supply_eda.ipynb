# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# #### Importing the dataset

# %%
#Africa Food Supply
afs_data = pd.read_excel('./Africa Food Supply (2004 - 2013).xlsx', index_col = None, header = 0)
afs_data = afs_data[2:]
afs_data.columns = ["Country","Year","Value"]

# %%
afs_data
# Out:
#       Country  Year Value
# 2     Algeria  2004  2987
# 3     Algeria  2005  2958
# 4     Algeria  2006  3047
# 5     Algeria  2007  3041
# 6     Algeria  2008  3048
# ..        ...   ...   ...
# 462  Zimbabwe  2010  2168
# 463  Zimbabwe  2011  2200
# 464  Zimbabwe  2012  2197
# 465       NaN   NaN   NaN
# 466  Zimbabwe  2013  2110
#
# [465 rows x 3 columns]

# %% [markdown]
# #### Check and Remove NaN values

# %%
afs_data.isnull().sum()
# Out:
# Country    15
# Year       15
# Value      15
# dtype: int64

# %%
afs_data.dropna(inplace = True)

# %%
afs_data['Year'] = pd.to_datetime(afs_data['Year'],format='%Y')
afs_data['Year'] = pd.DatetimeIndex(afs_data['Year']).year
afs_data["Value"] = pd.to_numeric(afs_data["Value"])

# %%
afs_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 450 entries, 2 to 466
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  450 non-null    object
#  1   Year     450 non-null    int64
#  2   Value    450 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 14.1+ KB

# %%
format_dict = {'Value': '{0:,.0f} kt'}
total_group = afs_data.groupby(["Country","Year"])[["Value"]].sum()
#total_sup = pd.DataFrame(total_group)
total_group.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6f384_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="index_name level1" >Year</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f384_level0_row0" class="row_heading level0 row0" rowspan="10">Algeria</th>
#       <th id="T_6f384_level1_row0" class="row_heading level1 row0" >2004</th>
#       <td id="T_6f384_row0_col0" class="data row0 col0" >2,987 kt</td>
#     </tr>
#     <tr>
#       <th id="T_6f384_level1_row1" class="row_heading level1 row1" >2005</th>
#       <td id="T_6f384_row1_col0" class="data row1 col0" >2,958 kt</td>
#     </tr>
#     <tr>
#       <th id="T_6f384_level1_row2" class="row_heading level1 row2" >2006</th>
# ...

# %%
plt.figure(figsize=(15,10))
sns.lineplot(data=total_group, x='Year', y='Value', hue='Country', style= 'Country')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Value'>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x=afs_data["Year"], y = afs_data["Value"])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Value'>

# %%
afs_data.groupby(["Year"])[["Value"]].sum().plot.bar(color = 'seagreen')
plt.title("Food Supply in AFrica 2004 - 2013")
plt.show()

# %%
afs_data.groupby(["Country"])[["Value"]].sum().sort_values(by = 'Value', ascending = False)
# Out:
#                             Value
# Country
# Egypt                       34580
# Tunisia                     33055
# Morocco                     32967
# Algeria                     31118
# Mauritius                   30543
# South Africa                29629
# Ghana                       29180
# Cote d'Ivoire               27666
# Mali                        27502
# Mauritania                  27443
# Gabon                       27299
# Nigeria                     26988
# Burkina Faso                26072
# Gambia                      25695
# Lesotho                     25588
# Cabo Verde                  25514
# Benin                       25378
# Guinea                      25180
# Niger                       25024
# Cameroon                    24603
# Sao Tome and Principe       24462
# Djibouti                    24165
# Senegal                     23784
# Togo                        23339
# Sudan                       23238
# Swaziland                   23171
# ...

# %%
# filtering = df['Team'] == "Boston Celtics"
# In [15]
#total_group.where(total_group["Year"]==2012)
high = afs_data['Value'].max()
year_sort = afs_data.query('Year==2012').sort_values('Value', ascending = False)
year_sort.style.format({'Value': '{0:,.0f} kt'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_4b35e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Country</th>
#       <th class="col_heading level0 col1" >Year</th>
#       <th class="col_heading level0 col2" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b35e_level0_row0" class="row_heading level0 row0" >134</th>
#       <td id="T_4b35e_row0_col0" class="data row0 col0" >Egypt</td>
#       <td id="T_4b35e_row0_col1" class="data row0 col1" >2012</td>
#       <td id="T_4b35e_row0_col2" class="data row0 col2" >3,561 kt</td>
#     </tr>
#     <tr>
#       <th id="T_4b35e_level0_row1" class="row_heading level0 row1" >423</th>
#       <td id="T_4b35e_row1_col0" class="data row1 col0" >Tunisia</td>
#       <td id="T_4b35e_row1_col1" class="data row1 col1" >2012</td>
#       <td id="T_4b35e_row1_col2" class="data row1 col2" >3,390 kt</td>
#     </tr>
#     <tr>
# ...

# %%
#Africa Food Supply
afs_data = pd.read_excel('./Africa Food Supply (2004 - 2013).xlsx', index_col = None, header = 0)
afs_data = afs_data[2:]
afs_data.columns = ["Country","Year","Value"]

# %%
afs_data
# Out:
#       Country  Year Value
# 2     Algeria  2004  2987
# 3     Algeria  2005  2958
# 4     Algeria  2006  3047
# 5     Algeria  2007  3041
# 6     Algeria  2008  3048
# ..        ...   ...   ...
# 462  Zimbabwe  2010  2168
# 463  Zimbabwe  2011  2200
# 464  Zimbabwe  2012  2197
# 465       NaN   NaN   NaN
# 466  Zimbabwe  2013  2110
#
# [465 rows x 3 columns]

# %% [markdown]
# #### Check and Remove NaN values

# %%
afs_data.isnull().sum()
# Out:
# Country    15
# Year       15
# Value      15
# dtype: int64

# %%
afs_data.dropna(inplace = True)

# %%
afs_data['Year'] = pd.to_datetime(afs_data['Year'],format='%Y')
afs_data['Year'] = pd.DatetimeIndex(afs_data['Year']).year
afs_data["Value"] = pd.to_numeric(afs_data["Value"])

# %%
afs_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 450 entries, 2 to 466
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  450 non-null    object
#  1   Year     450 non-null    int64
#  2   Value    450 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 14.1+ KB

# %%
total_group = afs_data.groupby(["Country","Year"])[["Value"]].sum()
#total_sup = pd.DataFrame(total_group)
total_group.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bd400_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="index_name level1" >Year</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd400_level0_row0" class="row_heading level0 row0" rowspan="10">Algeria</th>
#       <th id="T_bd400_level1_row0" class="row_heading level1 row0" >2004</th>
#       <td id="T_bd400_row0_col0" class="data row0 col0" >2,987 kt</td>
#     </tr>
#     <tr>
#       <th id="T_bd400_level1_row1" class="row_heading level1 row1" >2005</th>
#       <td id="T_bd400_row1_col0" class="data row1 col0" >2,958 kt</td>
#     </tr>
#     <tr>
#       <th id="T_bd400_level1_row2" class="row_heading level1 row2" >2006</th>
# ...

# %%
plt.figure(figsize=(15,10))
sns.lineplot(data=total_group, x='Year', y='Value', hue='Country', style= 'Country')
plt.title("Africa Food Supply by Country (2004 - 2013)")
# Out:
# Text(0.5, 1.0, 'Africa Food Supply by Country (2004 - 2013)')

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x=afs_data["Year"], y = afs_data["Value"])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Value'>

# %%
afs_data.groupby(["Year"])[["Value"]].sum().sort_values('Value', ascending = False).style.format({'Value': '{0:,.0f} kt'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_1836a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Year</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1836a_level0_row0" class="row_heading level0 row0" >2013</th>
#       <td id="T_1836a_row0_col0" class="data row0 col0" >113,951 kt</td>
#     </tr>
#     <tr>
#       <th id="T_1836a_level0_row1" class="row_heading level0 row1" >2012</th>
#       <td id="T_1836a_row1_col0" class="data row1 col0" >113,744 kt</td>
#     </tr>
#     <tr>
#       <th id="T_1836a_level0_row2" class="row_heading level0 row2" >2011</th>
#       <td id="T_1836a_row2_col0" class="data row2 col0" >113,194 kt</td>
#     </tr>
#     <tr>
#       <th id="T_1836a_level0_row3" class="row_heading level0 row3" >2010</th>
# ...

# %%
# filtering = df['Team'] == "Boston Celtics"
# In [15]
#total_group.where(total_group["Year"]==2012)
high = afs_data['Value'].max()
year_sort = afs_data.query('Year==2012').sort_values('Value', ascending = False)
year_sort.style.format({'Value': '{0:,.0f} kt'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_2bc1f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Country</th>
#       <th class="col_heading level0 col1" >Year</th>
#       <th class="col_heading level0 col2" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2bc1f_level0_row0" class="row_heading level0 row0" >134</th>
#       <td id="T_2bc1f_row0_col0" class="data row0 col0" >Egypt</td>
#       <td id="T_2bc1f_row0_col1" class="data row0 col1" >2012</td>
#       <td id="T_2bc1f_row0_col2" class="data row0 col2" >3,561 kt</td>
#     </tr>
#     <tr>
#       <th id="T_2bc1f_level0_row1" class="row_heading level0 row1" >423</th>
#       <td id="T_2bc1f_row1_col0" class="data row1 col0" >Tunisia</td>
#       <td id="T_2bc1f_row1_col1" class="data row1 col1" >2012</td>
#       <td id="T_2bc1f_row1_col2" class="data row1 col2" >3,390 kt</td>
#     </tr>
#     <tr>
# ...

# %%
country_grp = afs_data.groupby(["Country"])[["Value"]].sum().sort_values('Value', ascending = False)
country_grp.style.format({'Value': '{0:,.0f} kt'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_25d72_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25d72_level0_row0" class="row_heading level0 row0" >Egypt</th>
#       <td id="T_25d72_row0_col0" class="data row0 col0" >34,580 kt</td>
#     </tr>
#     <tr>
#       <th id="T_25d72_level0_row1" class="row_heading level0 row1" >Tunisia</th>
#       <td id="T_25d72_row1_col0" class="data row1 col0" >33,055 kt</td>
#     </tr>
#     <tr>
#       <th id="T_25d72_level0_row2" class="row_heading level0 row2" >Morocco</th>
#       <td id="T_25d72_row2_col0" class="data row2 col0" >32,967 kt</td>
#     </tr>
#     <tr>
#       <th id="T_25d72_level0_row3" class="row_heading level0 row3" >Algeria</th>
# ...

# %%
country_grp.to_csv('./country_group.csv')
